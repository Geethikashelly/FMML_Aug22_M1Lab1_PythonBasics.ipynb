# %% [markdown]
# <a href="https://colab.research.google.com/github/Geethikashelly/FMML_Aug22_M1Lab1_PythonBasics.ipynb/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-27 16:48:29--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   131MB/s    in 0.5s
#
# 2023-05-27 16:48:34 (131 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 12521  1802.07229v1  A generative model may generate utter nonsense...    cs
# 1953    1210.7053v2  Inference is an integral part of probabilistic...  stat
# 11262  1506.06707v2  Mixture of Experts (MoE) is a popular framewor...  stat
# 37903   1106.1674v1  Stochastic Kronecker graphs supply a parsimoni...  stat
# 13126  1611.03404v1  Celeste is a procedure for inferring astronomi...    cs
# ...             ...                                                ...   ...
# 22628  1703.01968v3  Entropy Search (ES) and Predictive Entropy Sea...  stat
# 6039   1606.04316v3  The machine learning community adopted the use...  stat
# 9052   1508.03868v3  Every culture and language is unique. Our work...    cs
# 7719   1802.10489v1  Suppose that we wish to estimate a vector $\ma...  stat
# 21886   1405.3952v1  We propose a new two stage algorithm LING for ...  stat
#
#                                                    title  year  \
# 12521    Actively Avoiding Nonsense in Generative Models  2018
# 1953   Managing sparsity, time, and quality of infere...  2012
# 11262                     Non-Normal Mixtures of Experts  2015
# 37903  Moment based estimation of stochastic Kronecke...  2011
# 13126  Learning an Astronomical Catalog of the Visibl...  2016
# ...                                                  ...   ...
# 22628  Max-value Entropy Search for Efficient Bayesia...  2017
# 6039   Time for a change: a tutorial for comparing mu...  2016
# 9052   Visual Affect Around the World: A Large-scale ...  2015
# 7719   As you like it: Localization via paired compar...  2018
# 21886  Fast Ridge Regression with Randomized Principa...  2014
#
#                                                 keywords
# 12521  [generative, likelihood, generating, distribut...
# 1953   [inference, probabilistic, efficient, algorith...
# 11262  [framework, heterogeneity, regression, classif...
# 37903  [stochastic, kronecker, parsimonious, distribu...
# 13126  [procedure, inferring, astronomical, scientifi...
# ...                                                  ...
# 22628  [predictive, empirically, successful, optimiza...
# 6039   [community, hypothesis, significance, statisti...
# 9052   [expressly, uniqueness, specifically, sentimen...
# 7719   [comparisons, estimating, observation, includi...
# 21886  [algorithm, regression, regression, experiment...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 12521    [generative, likelihood, generating, distribut...
# 1953     [inference, probabilistic, efficient, algorith...
# 11262    [framework, heterogeneity, regression, classif...
# 37903    [stochastic, kronecker, parsimonious, distribu...
# 13126    [procedure, inferring, astronomical, scientifi...
#                                ...
# 11962    [identification, stochastic, distributions, co...
# 1146     [important, preference, typically, represented...
# 37836    [regression, promising, technique, selection, ...
# 977      [introduced, criterion, attention, simplicity,...
# 11273    [parametric, classification, regression, varia...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8612 words.
# Out of those 4538 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="b61bfacd-1de6-4c02-bce8-30c31ab7bea0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b61bfacd-1de6-4c02-bce8-30c31ab7bea0")) {                    Plotly.newPlot(                        "b61bfacd-1de6-4c02-bce8-30c31ab7bea0",                        [{"x":["polynomially","likelihood","exponentially","generating","constraint","distributions","distribution","generative","guarantees","probability","identifies","demonstrate","documents","nonconjugate","efficient","convergence","efficiently","challenging","representations","introduce","framework","incorporate","probabilistic","flexibility","knowledge","inference","algorithm","temperature","classification","unsuitable","expectation","maximizing","observations","practical","robustness","applications","dedicated","components","conditional","effectiveness","numerical","asymmetric","functions","anomalies","respectively","heterogeneity","usefulness","regarding","experiments","prediction","parameters","containing","clustering","following","algorithms","monotonically","simulated","presented","maximization","perception","regression","continuous","estimation","stochastic","parsimonious","typically","estimators","computationally","difficult","improvement","prominent","kronecker","especially","demanding","decomposing","parallelism","scientific","balancing","inferring","astronomical","statistically","notoriously","subproblems","computing","algorithmic","programming","constructs","distributed","procedure","innovations","posterior","implementation","effective","optimization","dimensional","searching","potential","selecting","relevance","expensive","predicted","processes","autonomous","experimental","important","maintained","threshold","optimizing","techniques","available","parameterized","maximally","described","experiment","quantified","informative","probabilities","phenomenon","hypothesize","represents","deterministic","receiving","explanations","representation","mechanistic","deviation","understanding","experiencing","specifying","cognition","representing","underlying","mechanisms","individual","occurrence","represent","comprehensive","observable","explanation","computational","estimates","correlation","derivation","dimension","performance","discussion","difference","excellent","similarities","coefficient","frequency","comparing","visualizing","different","discriminative","differences","relationship","summarize","qualitative","generator","procedures","suitability","projection","attenuation","radiation","recommended","information","transferable","corresponding","approaches","architectures","refinement","possibilities","perceptual","translation","evaluation","synthesize","synthesis","potentially","generators","reconstructed","resonance","modalities","similarity","outperforms","unsupervised","geographically","multilingual","identification","motivated","historical","linguistically","detecting","creativity","satisfying","objective","convolutional","generation","communicate","intelligence"],"y":[3,71,14,105,107,97,194,108,70,150,24,577,75,0,409,134,167,298,225,326,527,67,160,29,351,198,839,11,506,3,26,14,70,146,102,425,15,91,97,225,96,13,216,10,86,9,35,45,612,234,216,71,150,95,584,4,52,186,27,48,119,110,207,141,4,102,14,99,150,151,17,0,105,6,7,10,44,19,33,2,17,4,6,125,42,116,19,96,108,4,36,123,258,336,185,33,161,42,37,75,43,87,67,376,351,5,26,54,380,271,13,5,50,82,8,28,53,22,8,37,44,6,20,339,2,9,146,5,11,12,69,118,53,105,28,119,61,24,26,281,73,76,5,70,887,25,59,29,37,26,53,83,10,759,109,51,64,15,57,27,31,8,46,2,10,4,726,6,110,422,118,27,13,21,99,271,16,44,46,8,25,19,37,150,258,145,1,16,95,65,19,6,69,4,16,167,378,122,12,100],"type":"bar"},{"x":["polynomially","likelihood","exponentially","generating","constra ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4538,), (4538, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8175

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>DropoutDAgger</span> <span style=''>A</span> <span style=''>Bayesian</span> <span style=''>Approach</span> <span style=''>to</span> <span style=''>Safe</span> <span style='background-color:rgba(0, 255, 0, 0.4666666666666667);'>Imitation</span> <span style=''>Learning</span> <br/><br/><span style=''>While</span> <span style='background-color:rgba(0, 255, 0, 0.4666666666666667);'>imitation</span> <span style=''>learning</span> <span style=''>is</span> <span style=''>becoming</span> <span style=''>common</span> <span style=''>practice</span> <span style=''>in</span> <span style=''>robotics</span> <span style=''>this</span> <span style=''>approach</span> <span style=''>often</span> <span style=''>suffers</span> <span style=''>from</span> <span style=''>data</span> <span style=''>mismatch</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>compounding</span> <span style=''>errors</span> <span style=''>DAgger</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iterative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>addresses</span> <span style=''>these</span> <span style=''>issues</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.4999999999999999);'>continually</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>aggregating</span> <span style=''>training</span> <span style=''>data</span> <span style=''>from</span> <span style=''>both</span> <span style=''>the</span> <span style=''>expert</span> <span style=''>and</span> <span style=''>novice</span> <span style=''>policies</span> <span style=''>but</span> <span style=''>does</span> <span style=''>not</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>impact</span> <span style=''>of</span> <span style=''>safety</span> <span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extension</span> <span style=''>to</span> <span style=''>DAgger</span> <span style=''>which</span> <span style=''>uses</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.30215827338129503);'>distribution</span> <span style=''>over</span> <span style=''>actions</span> <span style=''>provided</span> <span style=''>by</span> <span style=''>the</span> <span style=''>novice</span> <span style=''>policy</span> <span style=''>for</span> <span style=''>a</span> <span style=''>given</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observation</span> <span style=''>Our</span> <span style=''>method</span> <span style=''>which</span> <span style=''>we</span> <span style=''>call</span> <span style=''>DropoutDAgger</span> <span style=''>uses</span> <span style=''>dropout</span> <span style=''>to</span> <span style=''>train</span> <span style=''>the</span> <span style=''>novice</span> <span style=''>as</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>that</span> <span style=''>provides</span> <span style=''>insight</span> <span style=''>to</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>confidence</span> <span style=''>Using</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.30215827338129503);'>distribution</span> <span style=''>over</span> <span style=''>the</span> <span style=''>novices</span> <span style=''>actions</span> <span style=''>we</span> <span style=''>estimate</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>measure</span> <span style=''>of</span> <span style=''>safety</span> <span style=''>with</span> <span style=''>respect</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Prediction</span> <span style=''>with</span> <span style=''>Missing</span> <span style=''>Data</span> <span style=''>via</span> <span style=''>Bayesian</span> <span style=''>Additive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regression</span> <span style=''>Trees</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporating</span> <span style=''>missing</span> <span style=''>data</span> <span style=''>in</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>learning</span> <span style=''>without</span> <span style=''>the</span> <span style=''>need</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>imputation</span> <span style=''>We</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>a</span> <span style=''>tree</span> <span style=''>based</span> <span style=''>method</span> <span style=''>Bayesian</span> <span style=''>Additive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regression</span> <span style=''>Trees</span> <span style=''>(BART)</span> <span style=''>enhanced</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Missingness</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Incorporated</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Attributes</span> <span style=''>an</span> <span style=''>approach</span> <span style=''>recently</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>missingness</span> <span style=''>into</span> <span style=''>decision</span> <span style=''>trees</span> <span style=''>(Twala</span> <span style=''>2008)</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>takes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>advantage</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partitioning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mechanisms</span> <span style=''>found</span> <span style=''>in</span> <span style=''>tree</span> <span style=''>based</span> <span style=''>models</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Simulations</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generated</span> <span style=''>models</span> <span style=''>and</span> <span style=''>real</span> <span style=''>data</span> <span style=''>indicate</span> <span style=''>that</span> <span style=''>our</span> <span style=''>proposed</span> <span style=''>method</span> <span style=''>can</span> <span style=''>forecast</span> <span style=''>well</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complicated</span> <span style=''>missing</span> <span style=''>at</span> <span style=''>random</span> <span style=''>and</span> <span style=''>not</span> <span style=''>missing</span> <span style=''>at</span> <span style=''>random</span> <span style=''>models</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>models</span> <span style=''>where</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>missingness</span> <span style=''>itself</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>influences</span> <span style=''>the</span> <span style=''>response</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>has</span> <span style=''>higher</span> <span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>More</span> <span style=''>Robust</span> <span style=''>Doubly</span> <span style=''>Robust</span> <span style=''>Off</span> <span style=''>policy</span> <span style='background-color:rgba(0, 255, 0, 0.4414893617021276);'>Evaluation</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>off</span> <span style=''>policy</span> <span style='background-color:rgba(0, 255, 0, 0.4414893617021276);'>evaluation</span> <span style=''>(OPE)</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.4183673469387755);'>reinforcement</span> <span style=''>learning</span> <span style=''>(RL)</span> <span style=''>where</span> <span style=''>the</span> <span style=''>goal</span> <span style=''>is</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>a</span> <span style=''>policy</span> <span style=''>from</span> <span style=''>the</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generated</span> <span style=''>by</span> <span style=''>another</span> <span style=''>policy(ies)</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>the</span> <span style=''>doubly</span> <span style=''>robust</span> <span style=''>(DR)</span> <span style='background-color:rgba(255, 0, 0, 0.6888888888888888);'>estimators</span> <span style=''>that</span> <span style=''>consist</span> <span style=''>of</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>sampling</span> <span style=''>(IS)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>and</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>model</span> <span style=''>and</span> <span style=''>utilize</span> <span style=''>the</span> <span style=''>low</span> <span style=''>(or</span> <span style=''>zero)</span> <span style=''>bias</span> <span style=''>of</span> <span style=''>IS</span> <span style=''>and</span> <span style=''>low</span> <span style=''>variance</span> <span style=''>of</span> <span style=''>the</span> <span style=''>model</span> <span style=''>at</span> <span style=''>the</span> <span style=''>same</span> <span style=''>time</span> <span style=''>Although</span> <span style=''>the</span> <span style=''>accuracy</span> <span style=''>of</span> <span style=''>the</span> <span style=''>model</span> <span style=''>has</span> <span style=''>a</span> <span style=''>huge</span> <span style=''>impact</span> <span style=''>on</span> <span style=''>the</span> <span style=''>overall</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>DR</span> <span style=''>most</span> <span style=''>of</span> <span style=''>the</span> <span style=''>work</span> <span style=''>on</span> <span style=''>using</span> <span style=''>the</span> <span style=''>DR</span> <span style='background-color:rgba(255, 0, 0, 0.6888888888888888);'>estimators</span> <span style=''>in</span> <span style=''>OPE</span> <span style=''>has</span> <span style=''>been</span> <span style=''>focused</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.30120481927710846);'>improving</span> <span style=''>the</span> <span style=''>IS</span> <span style=''>part</span> <span style=''>and</span> <span style=''>not</span> <span style=''>much</span> <span style=''>on</span> <span style=''>how</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>the</span> <span style=''>model</span> <span style=''>In</ ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Practical</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>for</span> <span style=''>Variable</span> <span style=''>Cost</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Objectives</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>black</span> <span style=''>box</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>with</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>environmental</span> <span style=''>variable</span> <span style=''>whose</span> <span style=''>value</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>determines</span> <span style=''>the</span> <span style=''>tradeoff</span> <span style=''>between</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <span style=''>cost</span> <span style=''>and</span> <span style=''>the</span> <span style=''>fidelity</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluations</span> <span style=''>Further</span> <span style=''>we</span> <span style=''>use</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>sampling</span> <span style=''>support</span> <span style=''>points</span> <span style=''>allowing</span> <span style=''>faster</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construction</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>acquisition</span> <span style=''>function</span> <span style=''>This</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>achieve</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>with</span> <span style=''>lower</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>overheads</span> <span style=''>than</span> <span style=''>previous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>and</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implemented</span> <span style=''>for</span> <span style=''>a</span> <span style=''>more</span> <span style=''>general</span> <span style=''>class</span> <span style=''>of</span> <span style=''>problem</span> <span style=''>We</span> <span style=''>show</span> <span style=''>this</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>synthetic</span> <span style=''>and</span> <span style=''>real</span> <span style=''>world</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>benchmark</span> <span style=''>problems</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12115796997855612)
# 	architecture (0.08041458184417441)
# 	processing (0.10650464617583988)
# 	challenging (0.10650464617583988)
# 	segmentation (0.07469621157969979)
# 	information (0.2594710507505361)
# 	detection (0.12294496068620443)
# 	different (0.271265189421015)
# 	recognition (0.1333095067905647)
# 	convolutional (0.135096497498213)
#
# Some Statistics words are:
# 	stochastic (0.13436563436563437)
# 	statistical (0.14785214785214784)
# 	algorithm (0.3931068931068931)
# 	estimation (0.16733266733266733)
# 	theoretical (0.14435564435564435)
# 	variables (0.14485514485514486)
# 	dimensional (0.1773226773226773)
# 	distribution (0.18081918081918083)
# 	inference (0.1993006993006993)
# 	regression (0.17932067932067933)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="127a8c86-2d8e-4063-a3c2-0e36a3f8dd02" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("127a8c86-2d8e-4063-a3c2-0e36a3f8dd02")) {                    Plotly.newPlot(                        "127a8c86-2d8e-4063-a3c2-0e36a3f8dd02",                        [{"x":["polynomially","likelihood","exponentially","generating","constraint","distributions","distribution","generative","guarantees","probability","identifies","demonstrate","documents","nonconjugate","efficient","convergence","efficiently","challenging","representations","introduce","framework","incorporate","probabilistic","flexibility","knowledge","inference","algorithm","temperature","classification","unsuitable","expectation","maximizing","observations","practical","robustness","applications","dedicated","components","conditional","effectiveness","numerical","asymmetric","functions","anomalies","respectively","heterogeneity","usefulness","regarding","experiments","prediction","parameters","containing","clustering","following","algorithms","monotonically","simulated","presented","maximization","perception","regression","continuous","estimation","stochastic","parsimonious","typically","estimators","computationally","difficult","improvement","prominent","kronecker","especially","demanding","decomposing","parallelism","scientific","balancing","inferring","astronomical","statistically","notoriously","subproblems","computing","algorithmic","programming","constructs","distributed","procedure","innovations","posterior","implementation","effective","optimization","dimensional","searching","potential","selecting","relevance","expensive","predicted","processes","autonomous","experimental","important","maintained","threshold","optimizing","techniques","available","parameterized","maximally","described","experiment","quantified","informative","probabilities","phenomenon","hypothesize","represents","deterministic","receiving","explanations","representation","mechanistic","deviation","understanding","experiencing","specifying","cognition","representing","underlying","mechanisms","individual","occurrence","represent","comprehensive","observable","explanation","computational","estimates","correlation","derivation","dimension","performance","discussion","difference","excellent","similarities","coefficient","frequency","comparing","visualizing","different","discriminative","differences","relationship","summarize","qualitative","generator","procedures","suitability","projection","attenuation","radiation","recommended","information","transferable","corresponding","approaches","architectures","refinement","possibilities","perceptual","translation","evaluation","synthesize","synthesis","potentially","generators","reconstructed","resonance","modalities","similarity","outperforms","unsupervised","geographically","multilingual","identification","motivated","historical","linguistically","detecting","creativity","satisfying","objective","convolutional","generation","communicate","intelligence","combination","visualization","divergence","modifications","summarized","superiority","outperformed","recognition","illustrated","categories","bidirectional","promising","recurrent","reflected","variational","contribute","developed","corrupted","empirically","diagnostics","influence","covariates","corruptions","subsampling","approximation","theoretically","randomized","motivates","influential","detection","improvements","reasoning","inherently","combining","processed","processing","facilitate","considered","extracted","significant","direction","solutions","answering","semantics","entailment","characterization","introduced","preferential","community","directions","alleviate","attention","barycenters","associated","conducted ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	nonconjugate
# 	kronecker
# 	barycenters
# 	determinants
# 	microarray
# 	substituting
# 	particulars
# 	confounders
# 	irreducible
# 	graphically
# 	mcallester
# 	monograph
# 	accounted
# 	seasonality
# 	impossibility
# 	underestimates
# 	underestimation
# 	criterions
# 	photovoltaic
# 	extrapolation
# Some words which never appear in Statistics papers:
# 	hypothesize
# 	attenuation
# 	regressive
# 	intriguing
# 	prisoners
# 	anticipated
# 	gathering
# 	experimented
# 	diacritical
# 	gazetteers
# 	substituted
# 	formations
# 	submissions
# 	laparoscopic
# 	facilities
# 	surgeries
# 	specifics
# 	adversarys
# 	occlusions
# 	disagreement

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0752198782212926e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7675
